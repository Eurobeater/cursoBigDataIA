# %% [markdown]
# # Práctica nº 3 Trabajando con la librería Pandas
#
# Si apareciera un conflicto con las librerías instaladas por defecto que impida usar pandas_profiling, se puede intentar solucionar instalando manualmente una versión posterior.\
#
# pip install pandas-profiling==indicar la versión  (por ejemplo: pip install pandas-profiling==2.7.1 )

# %% [markdown]
# ## Importar Pandas

# %%
import pandas as pd

pd.set_option("display.precision", 2)      # Display 2 decimals
pd.set_option('display.max_columns', 1000) # Display all variables

# %%
df = pd.read_csv('./data/telecom_churn.csv') #Cargamos los datos y creamos el DataFrame
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# > ### Ejercicio
# Documenta el dataset indicando en este apartado añadiendo aquí mismo la siguiente información:
# - Que información contiene
# - Traduce el significado de cada columna

# %% [markdown]
# ## shape (filas y columnas)
# Atención al print ¿Porqué usarlo?

# %%
print("Shape:", df.shape) # devuelve una tupla con el nº de filas y columnas
print("Number of rows:", df.shape[0]) # cuantas filas
print("Number of columns:", df.shape[1]) #cuantas columnas
# Out:
# Shape: (3333, 21)
# Number of rows: 3333
# Number of columns: 21

# %% [markdown]
# ## Variables o Features

# %%
print(df.columns)
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# ## Tipos de variables con `info()`

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(4)
# memory usage: 524.2+ KB
# None

# %% [markdown]
# ## Descripción del dataset con describe()

# %%
# Al ejecutar df.describe() obtendrás un nuevo DataFrame que te mostrará, para cada columna numérica
# count: El número de valores no nulos (es decir, los que no están vacíos).
# mean: El promedio de todos los valores.
# std: La desviación estándar, que te indica qué tan dispersos están los datos con respecto al promedio.
# min: El valor mínimo.
# 25%: El primer cuartil (el valor debajo del cual está el 25% de los datos).
# 50%: La mediana (el valor que divide los datos en dos partes iguales).
# 75%: El tercer cuartil (el valor debajo del cual está el 75% de los datos).
# max: El valor máximo.

df.describe()
# Out:
#        account length  area code  number vmail messages  total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# std              20.07              9.26              50.71            19.92
# min               0.00              0.00               0.00             0.00
# 25%              87.00             24.43             166.60            87.00
# 50%             101.00             30.50             201.40           100.00
# 75%             114.00             36.79             235.30           114.00
# max             165.00             59.64             363.70           170.00
#
#        total eve charge  total night minutes  total night calls  \
# count           3333.00              3333.00            3333.00
# mean              17.08               200.87             100.11
# std                4.31                50.57              19.57
# min                0.00                23.20              33.00
# 25%               14.16               167.00              87.00
# 50%               17.12               201.20             100.00
# 75%               20.00               235.30             113.00
# max               30.91               395.00             175.00
#
#        total night charge  total intl minutes  total intl calls  \
# count             3333.00             3333.00           3333.00
# mean                 9.04               10.24              4.48
# std                  2.28                2.79              2.46
# min                  1.04                0.00              0.00
# 25%                  7.52                8.50              3.00
# 50%                  9.05               10.30              4.00
# 75%                 10.59               12.10              6.00
# max                 17.77               20.00             20.00
#
#        total intl charge  customer service calls
# count            3333.00                 3333.00
# mean                2.76                    1.56
# std                 0.75                    1.32
# min                 0.00                    0.00
# 25%                 2.30                    1.00
# 50%                 2.78                    1.00
# 75%                 3.27                    2.00
# max                 5.40                    9.00

# %% [markdown]
# ## Selecionar una variable

# %%
df["state"]
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: state, Length: 3333, dtype: object

# %% [markdown]
# ## Selecionar multiples variables
#
# El siguiente código contiene un error. ¿Podrías averiguar cual es?

# %%
df[["state", "account length", "Area code"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[["state", "account length", "Area code"]]
#
# File c:\Users\Buhardilla\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Buhardilla\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Buhardilla\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Area code'] not in index"

# %% [markdown]
# ## Variables numericas -> Min, max, mean, median, std, ...
#
# El siguiente código contiene errores. ¿Podrías averiguar cual es?

# %%
df['Account length'].min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Buhardilla\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Account length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Account length'].min()
#
# File c:\Users\Buhardilla\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Buhardilla\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Account length'

# %%
df['Account length'].max()

# %%
df['Account length'].mean()

# %%
df['Account length'].median()

# %%
df['Account length'].std()

# %% [markdown]
# ## Variables categoricas

# %%
df['churn'].value_counts()

# %%
df['churn'].value_counts(normalize=True) # Normaliza la salida mostrando el valor en porcentual

# %% [markdown]
# ## Filtrado

# %%
df[df['total day minutes'] > 100]  # Filtrar

# %%
df[(df['total day minutes'] > 100) & (df['churn'] == True) & (df['area code'] == 415)]  # Filtrar
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 48      ID             119        415     398-1294                 no
# 54      WY              87        415     353-3759                 no
# 76      DC              82        415     374-5353                 no
# ...    ...             ...        ...          ...                ...
# 3265    ID              82        415     408-1913                 no
# 3268    WA              84        415     367-5226                 no
# 3287    KS             170        415     404-5840                 no
# 3301    CA              84        415     417-1488                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 10                no                      0              129.1
# 15                no                      0              332.9
# 48                no                      0              159.1
# 54                no                      0              151.0
# 76                no                      0              300.3
# ...              ...                    ...                ...
# 3265              no                      0              266.9
# 3268              no                      0              289.1
# 3287             yes                     42              199.5
# 3301              no                      0              280.0
# 3323              no                      0              118.4
#
#       total day calls  total day charge  total eve minutes  total eve calls  \
# 10                137             21.95              228.5               83
# 15                 67             56.59              317.8               97
# 48                114             27.05              231.3              117
# 54                 83             25.67              219.7              116
# 76                109             51.05              181.0              100
# ...               ...               ...                ...              ...
# 3265               83             45.37              229.7               74
# 3268              100             49.15              233.8               97
# 3287              119             33.92              135.0               90
# 3301              113             47.60              202.2               90
# 3323              126             20.13              249.3               97
#
#       total eve charge  total night minutes  total night calls  \
# 10               19.42                208.8                111
# 15               27.01                160.6                128
# 48               19.66                143.2                 91
# 54               18.67                203.9                127
# 76               15.39                270.1                 73
# ...                ...                  ...                ...
# 3265             19.52                251.7                 99
# 3268             19.87                223.5                148
# 3287             11.48                184.6                 49
# 3301             17.19                156.8                103
# 3323             21.19                227.0                 56
#
#       total night charge  total intl minutes  total intl calls  \
# 10                  9.40                12.7                 6
# 15                  7.23                 5.4                 9
# 48                  6.44                 8.8                 3
# 54                  9.18                 9.7                 3
# 76                 12.15                11.7                 4
# ...                  ...                 ...               ...
# 3265               11.33                11.0                 6
# 3268               10.06                12.7                 2
# 3287                8.31                10.9                 3
# 3301                7.06                10.4                 4
# 3323               10.22                13.6                 3
#
#       total intl charge  customer service calls  churn
# 10                 3.43                       4   True
# 15                 1.46                       4   True
# 48                 2.38                       5   True
# 54                 2.62                       5   True
# 76                 3.16                       0   True
# ...                 ...                     ...    ...
# 3265               2.97                       3   True
# 3268               3.43                       2   True
# 3287               2.94                       4   True
# 3301               2.81                       0   True
# 3323               3.67                       5   True
#
# [226 rows x 21 columns]

# %% [markdown]
# ### Ejercicio
#
# Con el objetivo de tener un documento base de referencia, añadir a este notebook todas las funciones trabajadas en la práctica 2 referidas a la función pd.read_csv
# y reescribirlas para probar el dataset telecom_churn.csv
